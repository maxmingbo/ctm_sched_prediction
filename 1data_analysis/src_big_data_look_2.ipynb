# %% [markdown]
# ### 对原始大文件进行简单观察--20181020批次数据

# %%
#查看ajob表前几行
i = 0
day_set = set()
with open(r'E:\aevt\20181020_AJOB_TMP_000AH000.DAT') as file:
    for line in file:
        i = i+1
        day = line.split('|')[-2]  #倒数第二行是表的 日期+sever编码
        day_set.add(day[1:])
        print(line)
        print(day[:7])
        print(day[7:11])
        if i>2:
            break
# Out:
# 00t1a|Command|FW_TS_HFPF_HC03_VBSDTA_FPDEFNDTP|172566|180823|9|扫描抽取作业产生的标准文件|0|||00005M|20180828000206|sa|ds01|0|000000|Wait Condition|Run (1332)|0|20180827235700|20180827235705|1331|sh /DW_DXP/TOOL/script/adm/ctm/FileWatch.sh /DW_DXP/LINK/HQ/LH19/LH19/\$TX-DTE#YYYYMMDD# LH19_A_C03_VBSDTA_FPDEFNDTP_\$TX-DTE#YYYYMMDD#_000AH000.CTL %%DTE_D_YMD_8|0|1|GRP_DS_AGENT|DXP_FW_HFPF_LH19|20180823000214||0|1055|180827001|
#
# 180827
# 001
# 00w17|Command|TRZ_HRCA_RCM_OFFER_UP_DAY||180823|9|日常TR作业的压缩作业|0|||00020M||sa|GRP_DS_AGENT|20|000018|Wait Condition||0|||0|perl /DW_DXP/TOOL/script/prd/dxp_ex_tr_gz.pl TR_HRCA_RCM_OFFER_UP_DAY %%DTE_D_YMD_8|0|0|GRP_DS_AGENT|DXP_TR_HRCA_RTL3|20180823000214|104100|0|0|180827001|
#
# 180827
# 001
# 00x5a|Job|TR_HCGC_TTG_DDXX_860000025||180823|9|信用卡开放平台下传的默认数据文件格式字段内部有回车换行转换为交换平台标准文件|0|||00020M||sa|GRP_DS_AGENT|20|000102|Wait Condition||0|||0||0|0|GRP_DS_AGENT|DXP_TR_HCGC_LU25|20180823000214|172316|0|0|180827001|
#
# 180827
# 001

# %%
# job表 日期起始 --结束
i = 0
d_set = set()
with open(r'E:\aevt\20181020_AJOB_TMP_000AH000.DAT') as file:
    for line in file:
        d = line.split('|')[-2][1:]
        #if d > '2018-04-18':
        d_set.add(d)
print(sorted(list(d_set)))
# Out:
# ['180827001', '180827002', '180827003', '180828001', '180828002', '180828003', '180829001', '180829002', '180829003', '180830001', '180830002', '180830003', '180831001', '180831002', '180831003', '180901001', '180901002', '180901003', '180902001', '180902002', '180902003', '180903001', '180903002', '180903003', '180904001', '180904002', '180904003', '180905001', '180905002', '180905003', '180906001', '180906002', '180906003', '180907001', '180907002', '180907003', '180908001', '180908002', '180908003', '180909001', '180909002', '180909003', '180910001', '180910002', '180910003', '180911001', '180911002', '180911003', '180912001', '180912002', '180912003', '180913001', '180913002', '180913003', '180914001', '180914002', '180914003', '180915001', '180915002', '180915003', '180916001', '180916002', '180916003', '180917001', '180917002', '180917003', '180918001', '180918002', '180918003', '180919001', '180919002', '180919003', '180920001', '180920002', '180920003', '180921001', '180921002', '180921003', '180922001', '180922002', '180922003', '180923001', '180923002', '180923003', '180924001', '180924002', '180924003', '180925001', '180925002', '180925003', '180926001', '180926002', '180926003', '180927001', '180927002', '180927003', '180928001', '180928002', '180928003', '180929001', '180929002', '180929003', '180930001', '180930002', '180930003', '181001001', '181001002', '181001003', '181002001', '181002002', '181002003', '181003001', '181003002', '181003003', '181004001', '181004002', '181004003', '181005001', '181005002', '181005003', '181006001', '181006002', '181006003', '181007001', '181007002', '181007003', '181008001', '181008001_10', '181008002', '181008002_10', '181008003', '181008003_10', '181009001', '181009001_9', '181009002', '181009002_9', '181009003', '181009003_9', '181010001', '181010001_8', '181010002', '181010002_8', '181010003', '181010003_8', '181011001', '181011001_7', '181011002', '181011002_7', '181011003', '181011003_7', '181012001', '181012001_6', '181012002', '181012002_6', '181012003', '181012003_6', '181013001', '181013002', '181013003', '181014001', '181014002', '181014003', '181015001', '181015001_10', '181015002', '181015002_10', '181015003', '181015003_10', '181016001', '181016001_9', '181016002', '181016002_9', '181016003', '181016003_9', '181017001', '181017001_8', '181017002', '181017002_8', '181017003', '181017003_8', '181018001', '181018001_7', '181018002', '181018002_7', '181018003', '181018003_7', '181019001', '181019001_6', '181019002', '181019002_6', '181019003', '181019003_6', '181020001', '181020002', '181020003', '181021001', '181021002', '181021003']

# %%
# job表 日期起始 --结束       有时间截取
i = 0
d_set = set()
with open(r'E:\aevt\20181020_AJOB_TMP_000AH000.DAT') as file:
    for line in file:
        d = line.split('|')[-2][1:]
        #if d > '2018-04-18':
        if len(d)>10:
            d_set.add(d)
print(sorted(list(d_set)))
# Out:
# ['181008001_10', '181008002_10', '181008003_10', '181009001_9', '181009002_9', '181009003_9', '181010001_8', '181010002_8', '181010003_8', '181011001_7', '181011002_7', '181011003_7', '181012001_6', '181012002_6', '181012003_6', '181015001_10', '181015002_10', '181015003_10', '181016001_9', '181016002_9', '181016003_9', '181017001_8', '181017002_8', '181017003_8', '181018001_7', '181018002_7', '181018003_7', '181019001_6', '181019002_6', '181019003_6']

# %%
#查看排序后的数据日期
d_list = sorted(list(d_set))
i = 1
for d in d_list:
    if i%3==0:
        print(d)
    else:
        print(d,end=',')
    i += 1
# Out:
# 180827001,180827002,180827003
# 180828001,180828002,180828003
# 180829001,180829002,180829003
# 180830001,180830002,180830003
# 180831001,180831002,180831003
# 180901001,180901002,180901003
# 180902001,180902002,180902003
# 180903001,180903002,180903003
# 180904001,180904002,180904003
# 180905001,180905002,180905003
# 180906001,180906002,180906003
# 180907001,180907002,180907003
# 180908001,180908002,180908003
# 180909001,180909002,180909003
# 180910001,180910002,180910003
# 180911001,180911002,180911003
# 180912001,180912002,180912003
# 180913001,180913002,180913003
# 180914001,180914002,180914003
# 180915001,180915002,180915003
# 180916001,180916002,180916003
# 180917001,180917002,180917003
# 180918001,180918002,180918003
# 180919001,180919002,180919003
# 180920001,180920002,180920003
# 180921001,180921002,180921003
# 180922001,180922002,180922003
# 180923001,180923002,180923003
# 180924001,180924002,180924003
# 180925001,180925002,180925003
# 180926001,180926002,180926003
# 180927001,180927002,180927003
# 180928001,180928002,180928003
# 180929001,180929002,180929003
# 180930001,180930002,180930003
# 181001001,181001002,181001003
# 181002001,181002002,181002003
# 181003001,181003002,181003003
# 181004001,181004002,181004003
# 181005001,181005002,181005003
# 181006001,181006002,181006003
# 181007001,181007002,181007003
# 181008001,181008001_10,181008002
# 181008002_10,181008003,181008003_10
# 181009001,181009001_9,181009002
# 181009002_9,181009003,181009003_9
# 181010001,181010001_8,181010002
# 181010002_8,181010003,181010003_8
# 181011001,181011001_7,181011002
# 181011002_7,181011003,181011003_7
# 181012001,181012001_6,181012002
# 181012002_6,181012003,181012003_6
# 181013001,181013002,181013003
# 181014001,181014002,181014003
# 181015001,181015001_10,181015002
# 181015002_10,181015003,181015003_10
# 181016001,181016001_9,181016002
# 181016002_9,181016003,181016003_9
# 181017001,181017001_8,181017002
# 181017002_8,181017003,181017003_8
# 181018001,181018001_7,181018002
# 181018002_7,181018003,181018003_7
# 181019001,181019001_6,181019002
# 181019002_6,181019003,181019003_6
# 181020001,181020002,181020003
# 181021001,181021002,181021003

# %%
#查看排序后的数据日期  有时间截取
d_list = sorted(list(d_set))
i = 1
for d in d_list:
    if i%3==0:
        print(d)
    else:
        print(d,end=',')
    i += 1
# Out:
# 181008001_10,181008002_10,181008003_10
# 181009001_9,181009002_9,181009003_9
# 181010001_8,181010002_8,181010003_8
# 181011001_7,181011002_7,181011003_7
# 181012001_6,181012002_6,181012003_6
# 181015001_10,181015002_10,181015003_10
# 181016001_9,181016002_9,181016003_9
# 181017001_8,181017002_8,181017003_8
# 181018001_7,181018002_7,181018003_7
# 181019001_6,181019002_6,181019003_6

# %%
#日期 集合输出：
d_set = list(set([d[:6] for d in d_list]))
print(sorted(d_set))
# Out:
# ['180827', '180828', '180829', '180830', '180831', '180901', '180902', '180903', '180904', '180905', '180906', '180907', '180908', '180909', '180910', '180911', '180912', '180913', '180914', '180915', '180916', '180917', '180918', '180919', '180920', '180921', '180922', '180923', '180924', '180925', '180926', '180927', '180928', '180929', '180930', '181001', '181002', '181003', '181004', '181005', '181006', '181007', '181008', '181009', '181010', '181011', '181012', '181013', '181014', '181015', '181016', '181017', '181018', '181019', '181020', '181021']

# %%
#日期 集合输出：有时间截取
d_set = list(set([d[:6] for d in d_list]))
print(sorted(d_set))
# Out:
# ['181008', '181009', '181010', '181011', '181012', '181015', '181016', '181017', '181018', '181019']

# %%
#ARES_Q_TMP_20180424.DAT  资源表前几行
i = 0
with open(r'E:\aevt\ARES_Q_TMP_20180715.DAT') as file:
    for line in file:
        i = i+1
        if i>3:
            break
        print(line)
# Out:
# QTY_DXP_SVR_WRITE_DGW|D|0|1||||180602001|
#
# DXP101|D|0|0||||180602001|
#
# DXP_6750_OUT1_BAS3|D|0|1000||||180602001|

# %%
# ALNKI_Q_TMP_20180715  作业 相 关联资源表

i = 0
with open(r'E:\aevt\ALNKI_Q_TMP_20180715.DAT') as file:
    for line in file:
        i = i+1
        if i>3:
            break
        print(line)
# Out:
# 40lai|QTY_DXP_JOB_LDELS_WEP|1|3448|||180602001|
#
# 41grj|QTY_TDDA_M_JOB_CNT|1|3467|||180602001|
#
# 3ytnt|QTY_TDDA_M_JOB_CNT|1|3489|||180602001|

# %%
# 事件表 前几行
i = 0
day_set = set()
with open(r'E:\aevt\AEVT_TMP_20180715.DAT') as file:
    for line in file:
        i = i+1
        #day = line.split('|')[-2]
        #day_set.add(day[1:])
        if i>3:
            break
        print(line)
# Out:
# 805|2018-06-02 00:20:28.000000|S|1|32|3xy6w|||180602001|
#
# 809|2018-06-02 00:20:29.000000|S|1|32|40005|1|3723967|180602001|
#
# 813|2018-06-02 00:20:29.000000|S|1|32|3ymrt|||180602001|

# %%
# 依赖关系表   输入

i = 0
with open(r'E:\aevt\ALNKI_P_TMP_20180715.DAT') as file:
    for line in file:
        i = i+1
        if i>3:
            break
        print(line)
# Out:
# 41f8j|EXM_P_HWHC_8_WEAPP7_WE2_CUS_KYC_ANS_D-TO-EXZ_P_HWHC_8_WEAPP7_WE2_CUS_KYC_ANS_D|0602|A|||180602001|
#
# 41fgs|FW_LD_TDW_1_P_HWHC_8_WEAPP7_WE2_CUS_EXAM_SCO_LOG_D-TO-LD_TDW_1_P_HWHC_8_WEAPP7_WE2_CUS_EXAM_SCO_LOG_D|0602|A|||180602001|
#
# 3z3l9|TRM_CRDA_ODOMA24U-TO-TRZ_CRDA_ODOMA24U|0601|A|||180602001|

# %%
# 依赖关系表  输出

i = 0
with open(r'E:\aevt\ALNKO_P_TMP_20180715.DAT') as file:
    for line in file:
        i = i+1
        if i>3:
            break
        print(line)
# Out:
# 41gua|EXM_T_HTDW_ARTP_ARTP_I_RMP_DMN_CM_HDV_INC_M_SR-TO-EXZ_T_HTDW_ARTP_ARTP_I_RMP_DMN_CM_HDV_INC_M_SR|0602|+|3626|180602001|
#
# 40oq9|TS_HEES_HTDW_AMDS_AMDS_CA311001_A001_MASRUN_01-TO-SYS_FW_TS_HEES_HTDW_AMDS_AMDS_CA311001_A001_MASRUN_01|0601|+|3685|180602001|
#
# 41gzs|EXM_T_HTDW_ARTP_ARTP_I_RT_NDM_IMP_VST_DTL-TO-EXZ_T_HTDW_ARTP_ARTP_I_RT_NDM_IMP_VST_DTL|0602|-|3748|180602001|

# %%
# 总资源表查看

i = 0
with open(r'E:\jupyter\CTM\data_src\resorce\ARES_Q_TMP_20180715.DAT') as file:
    for line in file:
        i = i+1
        if i>3:
            break
        print(line)
# Out:
# QTY_DXP_SVR_WRITE_DGW|D|0|1||||180602001|
#
# DXP101|D|0|0||||180602001|
#
# DXP_6750_OUT1_BAS3|D|0|1000||||180602001|

# %%
i = 0
with open(r'E:\jupyter\CTM\data_src\resorce\ARES_Q_TMP_20180825.DAT') as file:
    for line in file:
        i = i+1
        if i>3:
            break
        print(line)
# Out:
# QTY_DXP_SVR_WRITE_RCR|D|2|5||||180716001|
#
# QTY_DXP_SVR_PRCS_WEP@ds03|D|0|120||||180716001|
#
# QTY_DXP_SVR_PRCS_WEP@dssapp2|D|0|50||||180716001|

# %%
import pandas as pd
f = open(r'E:\jupyter\CTM\data_src\resorce\ARES_Q_TMP_20180825.DAT')
res = pd.read_csv(f, sep='|',header=None)
res = res[[0,1,3,7]]
res.columns = ('resource','D','max_res','v_day')
res['D'] = res['D'].apply(lambda x:x[1:])
res['max_res'] = res['max_res'].apply(lambda x:x[1:])
res['server'] = res['v_day'].apply(lambda x:x[7:10])
res['v_day'] = res['v_day'].apply(lambda x:x[1:7])
print(res.head())

res.to_csv(r'E:\jupyter\CTM\data_src\resorce\res_0825.csv',index=False)
# Out:
#                        resource  D max_res   v_day server
# 0         QTY_DXP_SVR_WRITE_RCR  D       5  180716    001
# 1     QTY_DXP_SVR_PRCS_WEP@ds03  D     120  180716    001
# 2  QTY_DXP_SVR_PRCS_WEP@dssapp2  D      50  180716    001
# 3          QTY_DXP_DB_READ_NAG1  D       8  180716    001
# 4         QTY_DXP_SVR_WRITE_CCF  D      20  180716    001
